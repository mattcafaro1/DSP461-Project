# %%
# !pip install numpy
# !pip install matplotlib
# !pip install tensorflow
# !pip install opencv-python

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras import datasets, layers, models
import pandas as pd

# %%
import os

folder_train = "C:\\Users\\mattc\\1 Project\\DSP Project\\train"
folder_train_path = os.listdir(folder_train)
header_number = 1
training_images = []
training_labels = []

# KEEP EQUAL TO 75 BECAUSE THATS HOW MANY HEARTS THERE ARE
number = 75

n = 0

# START LOOP #
for i in folder_train_path:
    # IDENTIFYING HEADER OF EACH FOLDER
    print(str(header_number)+ '. - ' + i.upper() + ': ' + str(number) + ' Images Saved')
    header_number = header_number + 1

    # SET CARD_FOLDER
    card_folder = (folder_train + '/' +i)
    card_folder_path = os.listdir(card_folder)
    #header_number = header_number + 1

    number = 1

    for x in card_folder_path[:119]:
        #print(number)

        ### SAVE THE IMAGE AND CONVERT COLOR ###
        img = cv2.imread(card_folder + '/' + x, cv2.IMREAD_COLOR)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        img = img / 255

        # TO SEE THE FOLDER
        #print(card_folder)

        ## TO SEE THE ARRAY ##
        #print(img)

        # IDENTIFY RANK OF CARD
        card_rank_id = card_folder.split('/')[1]
        card_rank_id = card_rank_id.split()[0]
        #print(card_rank)

        # ADD IMAGE AND LABEL TO TRAINING IMAGE LIST
        training_images.append(img)
        training_labels.append(card_rank_id)
        
        number = number + 1

        # VERIFY CARD RANK MATCHES CARD FOLDER FOR LIMITED NUMBER
        if n % 50 == 0:
            print(training_labels[n], card_folder.split('/')[1])
        n = n + 1
# Out:
# 1. - ACE OF CLUBS: 75 Images Saved
# ace ace of clubs
# ace ace of clubs
# ace ace of clubs
# 2. - ACE OF DIAMONDS: 120 Images Saved
# ace ace of diamonds
# ace ace of diamonds
# 3. - ACE OF HEARTS: 120 Images Saved
# ace ace of hearts
# ace ace of hearts
# ace ace of hearts
# 4. - ACE OF SPADES: 120 Images Saved
# ace ace of spades
# ace ace of spades
# 5. - EIGHT OF CLUBS: 120 Images Saved
# eight eight of clubs
# eight eight of clubs
# 6. - EIGHT OF DIAMONDS: 120 Images Saved
# eight eight of diamonds
# eight eight of diamonds
# eight eight of diamonds
# 7. - EIGHT OF HEARTS: 120 Images Saved
# eight eight of hearts
# eight eight of hearts
# 8. - EIGHT OF SPADES: 120 Images Saved
# eight eight of spades
# eight eight of spades
# eight eight of spades
# 9. - FIVE OF CLUBS: 120 Images Saved
# five five of clubs
# five five of clubs
# 10. - FIVE OF DIAMONDS: 120 Images Saved
# five five of diamonds
# five five of diamonds
# 11. - FIVE OF HEARTS: 120 Images Saved
# ...

# %%
## VALIDATION DATA
import os

folder_train = "C:\\Users\\mattc\\1 Project\\DSP Project\\valid"
folder_train_path = os.listdir(folder_train)
header_number = 1
valid_images = []
valid_labels = []

# KEEP EQUAL TO 6 BECAUSE THATS HOW MANY HEARTS THERE ARE
number = 6

n = 0

# START LOOP #
for i in folder_train_path:
    # IDENTIFYING HEADER OF EACH FOLDER
    print(str(header_number)+ '. - ' + i.upper() + ': ' + str(number) + ' Images Saved')
    header_number = header_number + 1

    # SET CARD_FOLDER
    card_folder = (folder_train + '/' +i)
    card_folder_path = os.listdir(card_folder)
    #header_number = header_number + 1

    number = 1

    for x in card_folder_path:
        #print(number)

        ### SAVE THE IMAGE AND CONVERT COLOR ###
        img = cv2.imread(card_folder + '/' + x, cv2.IMREAD_COLOR)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        img = img / 255

        # TO SEE THE FOLDER
        #print(card_folder)

        ## TO SEE THE ARRAY ##
        #print(img)

        # IDENTIFY RANK OF CARD
        card_rank_id = card_folder.split('/')[1]
        card_rank_id = card_rank_id.split()[0]
        #print(card_rank)

        # ADD IMAGE AND LABEL TO TRAINING IMAGE LIST
        valid_images.append(img)
        valid_labels.append(card_rank_id)
        
        number = number + 1

        # VERIFY CARD RANK MATCHES CARD FOLDER FOR LIMITED NUMBER
        if n % 5 == 0:
            print(valid_labels[n], card_folder.split('/')[1])
        n = n + 1

# %%
for i in range(2000):
    if i % 150 == 0:
        plt.imshow(training_images[i])
        plt.xticks([])
        plt.yticks([])

        plt.show()
        print(training_labels[i])
        print()
        print()


# BETTER VERSION #
idxs = np.arange(2000)

for i in range(50):
    plt.subplot(5,10, i+1)
    plt.xticks([])
    plt.yticks([])
    choice = np.random.choice(idxs)
    plt.imshow(training_images[choice])
    plt.xlabel(training_labels[choice])

plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_32828\1556706793.py in <module>
#       1 for i in range(2000):
#       2     if i % 150 == 0:
# ----> 3         plt.imshow(training_images[i])
#       4         plt.xticks([])
#       5         plt.yticks([])
#
# IndexError: list index out of range

# %%
# CHANGE TRAINING LABELS

training_images = np.array(training_images)
#training_labels = np.array(training_labels)
n = -1
for i in training_labels:
    n = n + 1
    if i == 'ace':
        training_labels[n] = 0
    elif i == 'two':
        training_labels[n] = 1
    elif i == 'three':
        training_labels[n] = 2
    elif i == 'four':
        training_labels[n] = 3
    elif i == 'five':
        training_labels[n] = 4
    elif i == 'six':
        training_labels[n] = 5
    elif i == 'seven':
        training_labels[n] = 6
    elif i == 'eight':
        training_labels[n] = 7
    elif i == 'nine':
        training_labels[n] = 8
    elif i == 'ten':
        training_labels[n] = 9
    elif i == 'jack':
        training_labels[n] = 10
    elif i == 'queen':
        training_labels[n] = 11
    elif i == 'king':
        training_labels[n] = 12
    elif i == 'joker':
        training_labels[n] = 13
training_labels = np.array(training_labels)
print(training_labels)
# Out:
# []

# %%
# CHANGE VALID LABELS

valid_images = np.array(valid_images)
#valid_labels = np.array(valid_labels)
n = -1
for i in valid_labels:
    n = n + 1
    if i == 'ace':
        valid_labels[n] = 0
    elif i == 'two':
        valid_labels[n] = 1
    elif i == 'three':
        valid_labels[n] = 2
    elif i == 'four':
        valid_labels[n] = 3
    elif i == 'five':
        valid_labels[n] = 4
    elif i == 'six':
        valid_labels[n] = 5
    elif i == 'seven':
        valid_labels[n] = 6
    elif i == 'eight':
        valid_labels[n] = 7
    elif i == 'nine':
        valid_labels[n] = 8
    elif i == 'ten':
        valid_labels[n] = 9
    elif i == 'jack':
        valid_labels[n] = 10
    elif i == 'queen':
        valid_labels[n] = 11
    elif i == 'king':
        valid_labels[n] = 12
    elif i == 'joker':
        valid_labels[n] = 13
valid_labels = np.array(valid_labels)
print(valid_labels)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_32828\2714052782.py in <module>
#       1 # CHANGE VALID LABELS
#       2
# ----> 3 valid_images = np.array(valid_images)
#       4 #valid_labels = np.array(valid_labels)
#       5 n = -1
#
# NameError: name 'valid_images' is not defined

# %%
## CHECK TRAINING IMAGES

idxs = np.arange(2000)
for i in range(50):
    x = np.random.choice(idxs)
    plt.imshow(training_images[x])
    plt.show()
    print(training_labels[x])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_32828\701836997.py in <module>
#       4 for i in range(50):
#       5     x = np.random.choice(idxs)
# ----> 6     plt.imshow(training_images[x])
#       7     plt.show()
#       8     print(training_labels[x])
#
# IndexError: index 438 is out of bounds for axis 0 with size 0

# %%
# CHECK VALIDATION IMAGES

idxs = np.arange(50)
for i in range(50):
    x = np.random.choice(idxs)
    plt.imshow(valid_images[x])
    plt.show()
    print(valid_labels[x])

# %%
class_names = ['ace', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine', 'ten', 'jack', 'queen', 'king', 'joker']

### MAIN MODULE ###

# Set Model Type
model = models.Sequential()

# LAYER 1
model.add(layers.Conv2D(32, (3,3), activation = 'relu', input_shape = (224,224,3)))
model.add(layers.MaxPooling2D((2,2)))


# LAYER 2
model.add(layers.Conv2D(64, (3,3), activation = 'relu'))
model.add(layers.MaxPooling2D((2,2)))

# LAYER 3
model.add(layers.Conv2D(64, (3,3), activation = 'relu'))
model.add(layers.Flatten())

# BACK LAYER AND OUTPUT
model.add(layers.Dense(32, activation = 'relu'))
model.add(layers.Dense(14, activation = 'softmax'))

model.summary()
model.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])

history = model.fit(training_images, training_labels, validation_data=(valid_images, valid_labels), epochs = 18)


#model.save('main_image_classifier.model1')

# %%
model.save('classifier_best.model')

# %%
plt.plot(history.history['accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.show()

# %%
history.history.keys()

# %%
plt.plot(history.history['val_accuracy'])
plt.title('Validation Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.title('Validation Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.show()

# %%
plt.plot(history.history['val_loss'])
plt.title('Validation Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.show()

# %%
model = models.load_model('classifier_best.model')

folder_test = "C:\\Users\\Mitchell Buckert\\1 Project\\test"
folder_test_path = os.listdir(folder_test)
n = 0
total = 0
true = 0
for i in folder_test_path:
    card_folder = (folder_test + '/' +i)
    card_folder_path = os.listdir(card_folder)
    for x in card_folder_path:
        
        img = cv2.imread(card_folder + '/' + x, cv2.IMREAD_COLOR)
        #print(card_folder)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        n = n + 1
        prediction = model.predict(np.array([img])/ 255)

        card_rank_id = card_folder.split('/')[1]
        card_rank_id = card_rank_id.split()[0]

        class_names = ['ace', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine', 'ten', 'jack', 'queen', 'king', 'joker']
        index = np.argmax(prediction)

        
        total = total + 1

        if card_rank_id == class_names[index]:
            true = true + 1

        if n % 10 == 0:
            

            print('IMAGE:')
            plt.imshow(img)
            plt.show()

            print(card_rank_id)

            print('Prediction: ' + class_names[index])
            #print(img)
        
print(true)
print(total)
print(true / total)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13588/3845014871.py in <module>
# ----> 1 model = models.load_model('classifier_best.model')
#       2
#       3 folder_test = "C:\\Users\\Mitchell Buckert\\1 Project\\test"
#       4 folder_test_path = os.listdir(folder_test)
#       5 n = 0
#
# ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# ~\anaconda3\lib\site-packages\keras\saving\legacy\save.py in load_model(filepath, custom_objects, compile, options)
#     225                 if isinstance(filepath_str, str):
# ...

# %%
folder_demo = "C:\\Users\\mattc\\1 Project\\DSP Project\\test"
folder_demo_path = os.listdir(folder_demo)

ace = 4
two = 4
three = 4
four = 4
five = 4
six = 4
seven = 4
eight = 4
nine = 4
ten = 4
jack = 4
queen = 4
king = 4
joker = 2

count = 0

deck = 52


for i in folder_demo_path:
        print(i)
        img = cv2.imread(folder_demo + '/' + i, cv2.IMREAD_COLOR)
        
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        n = n + 1
        prediction = model.predict(np.array([img])/ 255)
        
        class_names = ['ace', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine', 'ten', 'jack', 'queen', 'king', 'joker']
        index = np.argmax(prediction)
        card = class_names[index]
        
        if card == 'ace':           
            ace = ace - 1
            count = count - 1
            deck = deck - 1

        elif card == 'two':
            two = two - 1
            count = count + 1
            deck = deck - 1

        elif card == 'three':
            three = three - 1
            count = count + 1
            deck = deck - 1

        elif card == 'four':
            four = four - 1
            count = count + 1
            deck = deck - 1

        elif card == 'five':
            five = five - 1
            count = count + 1
            deck = deck - 1

        elif card == 'six':
            six = six - 1
            count = count + 1
            deck = deck - 1

        elif card == 'seven':
            seven = seven - 1
            deck = deck - 1

        elif card == 'eight':
            eight = eight - 1
            deck = deck - 1

        elif card == 'nine':
            nine = nine - 1
            deck = deck - 1

        elif card == 'ten':
            ten = ten - 1
            count = count - 1
            deck = deck - 1

        elif card == 'jack':
            jack = jack - 1 
            count = count - 1
            deck = deck - 1

        elif card == 'queen':
            queen = queen - 1
            count = count - 1
            deck = deck - 1

        elif card == 'king':
            king = king - 1
            count = count - 1
            deck = deck - 1


print(deck)
print('The count is '+ str(count))

if ace > 0:
    print('There are '+ str(ace)+' aces in left in the deck.')
    print('The probability of an Ace is: ' + str(ace/deck))

if two > 0:
    print('There are '+ str(two)+' twos in left in the deck.')
    print('The probability of a Two is: ' + str(tw/deck))
    
if three > 0:
    print('There are '+ str(three)+' threes in left in the deck.')

if four > 0:
    print('There are '+ str(four)+' fours in left in the deck.')

if five > 0:
    print('There are '+ str(five)+' fives in left in the deck.')

if six > 0:
    print('There are '+ str(six)+' sixes in left in the deck.')

if seven > 0:
    print('There are '+ str(seven)+' sevens in left in the deck.')

if eight > 0:
    print('There are '+ str(eight)+' eights in left in the deck.')

if nine > 0:
    print('There are '+ str(nine)+' nines in left in the deck.')

if ten > 0:
    print('There are '+ str(ten)+' tens in left in the deck.')

if jack > 0:
    print('There are '+ str(jack)+' jacks in left in the deck.')

if queen > 0:
    print('There are '+ str(queen)+' queens in left in the deck.')

if king > 0:
    print('There are '+ str(king)+' kings in left in the deck.')
